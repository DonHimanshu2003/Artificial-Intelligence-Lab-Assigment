# %% [markdown]
# ### **LAB** ASSIGNMENT 3
# ### **HIMANSHU** BAWEJA
# ### **E20CSE212**

# %%
import os 
import re
import glob
from IPython.display import HTML
from base64 import b64encode
import IPython.display as ipd

# %%
glob.glob("*.txt")
# Out:
# ['final.txt']

# %%
glob.glob("*.txt")
# Out:
# ['final.txt']

# %%
files=glob.glob("/content/*.txt")

# %%
file1=[]
for i in files:
  file=open(i,"r")
  file1.extend(file.readlines())
  file.close()

# %%
file1
# Out:
# ['The Age of A.I. is an eight-episode American science documentary streaming television series narrated and hosted by American actor Robert Downey Jr.. The show covers the applications of artificial intelligence (AI) in various fields, like health, robotics, space-travel, food, disaster-prevention, and others. Each 30-45 minute episode covers several different areas of AI implementation under one broader topic. \n',
# ...

# %%
files3=[]
#preprossessing data

for i in file1:
  a=re.sub(r"[^a-zA-Z]+", ' ', i)
  files3.append(a)
files3
# Out:
# ['The Age of A I is an eight episode American science documentary streaming television series narrated and hosted by American actor Robert Downey Jr The show covers the applications of artificial intelligence AI in various fields like health robotics space travel food disaster prevention and others Each minute episode covers several different areas of AI implementation under one broader topic ',
# ...

# %%
wl=""
for i in open('final.txt'):
  data1=re.sub('[^A-Za-z]+',' ',i)
  wl=wl+data1.lower()+'\n'
wl=wl[:-1]

# %%
file2=open('afterfinal.txt',"w")
file2.write(wl)
file2.close()

# %%
from ipywidgets import Video
vide=Video.from_file("video.55.10.mp4", width=320, height=320)
vide
# Out:
# Video(value=b'\x00\x00\x00\x18ftypmp42\x00\x00\x00\x00mp42isom\x00\x00\x00\x18beam\x01\x00\x00\x00\x01\x00\x00…

# %%
import IPython
IPython.display.Audio('video.55.10.mp4')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>
