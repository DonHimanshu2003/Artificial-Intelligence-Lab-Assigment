# %% [markdown]
# ### Himanshu Baweja
#
# ### E20CSE212
#
# ### Week 4 Lab 2

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/communities.data", sep=",", header=None, na_values = "?")
df.to_csv("output.csv") 
df
# Out:
#       0     1        2                    3    4    ...   123  124   125   126   127
# 0       8   NaN      NaN         Lakewoodcity    1  ...  0.90  0.5  0.32  0.14  0.20
# 1      53   NaN      NaN          Tukwilacity    1  ...   NaN  NaN  0.00   NaN  0.67
# 2      24   NaN      NaN         Aberdeentown    1  ...   NaN  NaN  0.00   NaN  0.43
# 3      34   5.0  81440.0  Willingborotownship    1  ...   NaN  NaN  0.00   NaN  0.12
# 4      42  95.0   6096.0    Bethlehemtownship    1  ...   NaN  NaN  0.00   NaN  0.03
# ...   ...   ...      ...                  ...  ...  ...   ...  ...   ...   ...   ...
# 1989   12   NaN      NaN    TempleTerracecity   10  ...   NaN  NaN  0.00   NaN  0.09
# 1990    6   NaN      NaN          Seasidecity   10  ...   NaN  NaN  0.00   NaN  0.45
# 1991    9   9.0  80070.0        Waterburytown   10  ...  0.78  0.0  0.91  0.28  0.23
# 1992   25  17.0  72600.0          Walthamcity   10  ...  0.79  0.0  0.22  0.18  0.19
# ...

# %%
#Drop: The first five attributes are non-predictive, hence drop them.
df = df.drop([0, 1, 2, 3, 4], axis = 1)
df
# Out:
#        5     6     7     8     9     10   ...   122   123  124   125   126   127
# 0     0.19  0.33  0.02  0.90  0.12  0.17  ...  0.04  0.90  0.5  0.32  0.14  0.20
# 1     0.00  0.16  0.12  0.74  0.45  0.07  ...   NaN   NaN  NaN  0.00   NaN  0.67
# 2     0.00  0.42  0.49  0.56  0.17  0.04  ...   NaN   NaN  NaN  0.00   NaN  0.43
# 3     0.04  0.77  1.00  0.08  0.12  0.10  ...   NaN   NaN  NaN  0.00   NaN  0.12
# 4     0.01  0.55  0.02  0.95  0.09  0.05  ...   NaN   NaN  NaN  0.00   NaN  0.03
# ...    ...   ...   ...   ...   ...   ...  ...   ...   ...  ...   ...   ...   ...
# 1989  0.01  0.40  0.10  0.87  0.12  0.16  ...   NaN   NaN  NaN  0.00   NaN  0.09
# 1990  0.05  0.96  0.46  0.28  0.83  0.32  ...   NaN   NaN  NaN  0.00   NaN  0.45
# 1991  0.16  0.37  0.25  0.69  0.04  0.25  ...  0.06  0.78  0.0  0.91  0.28  0.23
# 1992  0.08  0.51  0.06  0.87  0.22  0.10  ...  0.02  0.79  0.0  0.22  0.18  0.19
# 1993  0.20  0.78  0.14  0.46  0.24  0.77  ...  0.04  0.73  0.5  1.00  0.13  0.48
#
# ...

# %%
imputer = SimpleImputer(missing_values = np.nan,strategy ='mean')
imputer = imputer.fit(df)
df = imputer.transform(df)
df = pd.DataFrame(df)
df
# Out:
#        0     1     2     3     4    ...       118       119   120       121   122
# 0     0.19  0.33  0.02  0.90  0.12  ...  0.900000  0.500000  0.32  0.140000  0.20
# 1     0.00  0.16  0.12  0.74  0.45  ...  0.698589  0.440439  0.00  0.195078  0.67
# 2     0.00  0.42  0.49  0.56  0.17  ...  0.698589  0.440439  0.00  0.195078  0.43
# 3     0.04  0.77  1.00  0.08  0.12  ...  0.698589  0.440439  0.00  0.195078  0.12
# 4     0.01  0.55  0.02  0.95  0.09  ...  0.698589  0.440439  0.00  0.195078  0.03
# ...    ...   ...   ...   ...   ...  ...       ...       ...   ...       ...   ...
# 1989  0.01  0.40  0.10  0.87  0.12  ...  0.698589  0.440439  0.00  0.195078  0.09
# 1990  0.05  0.96  0.46  0.28  0.83  ...  0.698589  0.440439  0.00  0.195078  0.45
# 1991  0.16  0.37  0.25  0.69  0.04  ...  0.780000  0.000000  0.91  0.280000  0.23
# 1992  0.08  0.51  0.06  0.87  0.22  ...  0.790000  0.000000  0.22  0.180000  0.19
# ...

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn import metrics
kf = KFold(n_splits=10,shuffle=True)
mse = []
mae = []
mdae = []
r2 = []
for i,j in kf.split(df):
  train_x,test_x = X.loc[i],X.loc[j]
  train_y,test_y = y.loc[i],y.loc[j]
  lin = LinearRegression()
  lin.fit(train_x,train_y)
  lin = lin.predict(test_x)
  mse.append(round(metrics.mean_squared_error(test_y,lin),2))
  mae.append(round(metrics.mean_absolute_error(test_y,lin),2))
  mdae.append(round(metrics.median_absolute_error(test_y,lin),2))
  r2.append(round(metrics.r2_score(test_y,lin),2))
print("Average MSE =",round(np.mean(mse),2))
print("Average MAE =",round(np.mean(mae),2))
print("Average MDAE =",round(np.mean(mdae),2))
print("Average R2 =",round(np.mean(r2),2))
# Out:
# Average MSE = 0.42
# Average MAE = 0.11
# Average MDAE = 0.07
# Average R2 = -5.44

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
train_x, test_x, train_y, test_y = train_test_split(X,y,test_size=0.3)
lin = LinearRegression()
lin.fit(train_x,train_y)
a = lin.predict(test_x)
a_mse = round(metrics.mean_squared_error(test_y,a),2)
kf = KFold(n_splits=5,shuffle=True)
b_mse = []
for i,j in kf.split(df):
  train_x,test_x = X.loc[i],X.loc[j]
  train_y,test_y = y.loc[i],y.loc[j]
  lin.fit(train_x,train_y)
  b = lin.predict(test_x)
  b_mse.append(round(metrics.mean_squared_error(test_y,b),2))
b_mse = np.mean(b_mse)
kf = KFold(n_splits=10,shuffle=True)
c_mse = []
for i,j in kf.split(df):
  train_x,test_x = X.loc[i],X.loc[j]
  train_y,test_y = y.loc[i],y.loc[j]
  lin.fit(train_x,train_y)
  c = lin.predict(test_x)
  c_mse.append(round(metrics.mean_squared_error(test_y,c),2))
c_mse = np.mean(c_mse)
plt.title("Comparison of MSEs")
plt.bar(['Without K-Fold','5 split K-Fold','10 split K-Fold'],[a_mse,b_mse,c_mse])
# Out:
# <BarContainer object of 3 artists>

# %%
from sklearn.model_selection import cross_val_score
train_x, test_x, train_y, test_y = train_test_split(X,y,test_size=0.3)
lin = LinearRegression()
lin.fit(train_x,train_y)
a = lin.predict(test_x)
a_mse = cross_val_score(lin,test_x,test_y)
print("Predicted values =",a_mse)
# Out:
# Predicted values = [0.62339621 0.60685271 0.51395277 0.52472991 0.52599748]
